# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression(n_samples=20, n_features=1, noise=10)
reg = LinearRegression().fit(X_test, y_test)
reg.score(X_test, y_test)

reg.coef_

reg.intercept_

reg.predict(np.array([[3]]))
# Out:
# array([177.78015485])

# %%
x=X_test.tolist()
y=y_test.tolist()

# %%
# python code demonstrate creating
# dataframe from dict narrat/lists
# by default addresses

import pandas as pd
data = {'X': x,
        'Y': y}
# create dataframe
df = pd.DataFrame(data)

# %%
df.head(20)
# Out:
#                           X          Y
# 0      [0.2875799237700694]  27.105676
# 1    [0.013052202105659064]  -7.662841
# 2      [0.1330463512476182]   8.659478
# 3     [0.08627177543896211]  -0.531525
# 4   [-0.030651027002126584]   2.453356
# 5      [0.8013405053030986]  47.035012
# 6     [0.18164445027042642]  -9.104429
# 7   [-0.032264394776062556]   3.408255
# 8      [0.3034740415466583]  12.563649
# 9      [1.3186760494861807]  78.817398
# 10    [-1.0933305548396046] -62.826983
# 11    [0.43188635852629115]  52.584642
# 12     [0.2317666768103302]  18.544305
# 13    [-0.9249301147284682] -52.199085
# 14     [-1.422248107730919] -83.521416
# 15   [-0.09029057544042962]  10.404703
# 16      [1.616345607455237]  97.389512
# 17    [-0.6938996408323537] -45.373560
# 18     [1.0446912943772275]  55.661702
# 19    [-0.8269108604059123] -41.145492

# %%
reg.coef_
# Out:
# array([58.69522566])

# %%
reg.intercept_
# Out:
# 1.6944778642990306

# %%
pyplot.scatter(X_test,y_test)
Y_plot = reg.coef_*X_test+reg.intercept_
pyplot.plot(X_test, Y_plot, color='r')
pyplot.show()
